# %%
# System libraries:
# %load_ext autoreload
import pandas as pd
import json
import nltk
import numpy as np
import os
import sys
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
data = pd.read_csv('data/processed/integrum_processed.csv')
data.iloc[:5]
# Out:
#    id        date        MediaDetail MediaShort  \
# 0   1  01.11.2003  Известия (Москва)   Известия
# 1   2  03.11.2003  Известия (Москва)   Известия
# 2   3  04.11.2003  Известия (Москва)   Известия
# 3   4  05.11.2003  Известия (Москва)   Известия
# 4   5  06.11.2003  Известия (Москва)   Известия
#
#                                             headline  \
# 0  Владимир ВУЙТЕК, главный тренер хоккейного клу...
# 1                                   Судьба Маргариты
# 2                  Девушка в кокошнике - лицо России
# 3                                Не прошло и полвека
# 4                                            ХРОНИКА
#
#                                              content  \
# 0  О чешском тренере Владимире ВУЙТЕКЕ нынче прин...
# 1  В минувшее воскресенье исполнилось 110 лет со ...
# 2  В минувшие выходные в Греции завершилась 19-я ...
# 3  Сотрудники МИД Финляндии разыскали живого свид...
# 4  EXXON MOBIL НАМЕРЕНА РАЗВИВАТЬ СОТРУДНИЧЕСТВО ...
#
#                                      lemmas_headline  \
# 0  ['министр', 'окружающий', 'среда', 'ниинист', ...
# 1  ['финский', 'труд', 'дешево', 'труд', 'германия']
# 2  ['начинаться', 'постепенный', 'переход', 'летн...
# 3  ['в', 'надворный', 'суд', 'начинаться', 'разби...
# 4          ['летний', 'рабочий', 'место', 'хватать']
#
#                                       lemmas_content  \
# 0  ['министр', 'вопрос', 'окружающий', 'среда', '...
# 1  ['труд', 'финский', 'работник', 'занимать', '8...
# 2  ['на', 'дорога', 'южный', 'финляндия', 'летний...
# 3  ['в', 'хельсинкский', 'надворный', 'суд', 'нач...
# 4  ['несмотря', 'усилие', 'различный', 'кампания'...
#
#                                       tokens_content  \
# 0  ['О', 'чешском', 'тренере', 'Владимире', 'ВУЙТ...
# 1  ['В', 'минувшее', 'воскресенье', 'исполнилось'...
# 2  ['В', 'минувшие', 'выходные', 'Греции', 'завер...
# 3  ['Сотрудники', 'МИД', 'Финляндии', 'разыскали'...
# 4  ['EXXON', 'MOBIL', 'НАМЕРЕНА', 'РАЗВИВАТЬ', 'С...
#
#                                      tokens_headline
# 0  ['Владимир', 'ВУЙТЕК', 'главный', 'тренер', 'х...
# 1                            ['Судьба', 'Маргариты']
# 2         ['Девушка', 'кокошнике', 'лицо', 'России']
# 3                        ['Не', 'прошло', 'полвека']
# 4                                        ['ХРОНИКА']

# %%
#Get articles by keywords:

# Enter your search string:
search_string = 'переводчик'
results = data[data['content'].str.contains(search_string)]

# Get all results matching search string
results
# Out:
#           id        date                    MediaDetail  \
# 229      230  28.07.2004              Известия (Москва)
# 239      240  16.08.2004              Известия (Москва)
# 297      298  29.10.2004              Известия (Москва)
# 470      471  03.08.2005              Известия (Москва)
# 475      476  17.08.2005              Известия (Москва)
# 495      496  23.09.2005              Известия (Москва)
# 545      546  26.12.2005              Известия (Москва)
# 658      659  17.11.2006              Известия (Москва)
# 747      748  22.06.2007              Известия (Москва)
# 1174                        Известия
# 1205                        Известия
# 1302                        Известия
# 1345                        Известия
# 1423                        Известия
# 1444                        Известия
# 1467                        Известия
# 1822                        Известия
# 2191                        Известия
# 2285                        Известия
# 2881                     Коммерсантъ
# 3576                     Коммерсантъ
# 4386                     Коммерсантъ
# 4833                     Коммерсантъ
# 4841                     Коммерсантъ
# 4995                     Коммерсантъ
# ...                              ...
# 58923  Санкт-Петербургские Ведомости
# 59398  Санкт-Петербургские Ведомости
# 59465  Санкт-Петербургские Ведомости
# 59487  Санкт-Петербургские Ведомости
# 59490  Санкт-Петербургские Ведомости
# 59545  Санкт-Петербургские Ведомости
# 59656  Санкт-Петербургские Ведомости
# 59714  Санкт-Петербургские Ведомости
# 59767  Санкт-Петербургские Ведомости
# 59984  Санкт-Петербургские Ведомости
# 59991  Санкт-Петербургские Ведомости
# 60088  Санкт-Петербургские Ведомости
# 60109  Санкт-Петербургские Ведомости
# 60265  Санкт-Петербургские Ведомости
# 60352  Санкт-Петербургские Ведомости
# 60358  Санкт-Петербургские Ведомости
# 60417  Санкт-Петербургские Ведомости
# 60480  Санкт-Петербургские Ведомости
# 60482  Санкт-Петербургские Ведомости
# 60543  Санкт-Петербургские Ведомости
# 60621  Санкт-Петербургские Ведомости
# 60624  Санкт-Петербургские Ведомости
# 60636  Санкт-Петербургские Ведомости
# 60774  Санкт-Петербургские Ведомости
# 60868  Санкт-Петербургские Ведомости
# 60877  Санкт-Петербургские Ведомости
# 60917  Санкт-Петербургские Ведомости
# 60976  Санкт-Петербургские Ведомости
# 61002  Санкт-Петербургские Ведомости
# 61022  Санкт-Петербургские Ведомости
#
#                                                 headline  \
# 229    РОССИЙСКУЮ БАСКЕТБОЛЬНУЮ СБОРНУЮ ВО ФРАНЦИИ ПО...
# 239                                    УМЕР ЧЕСЛАВ МИЛОШ
# 297                             ДЕНЬ РОЖДЕНИЯ ПРОПАГАНДЫ
# 470                                 Президентский резерв
# 475    В Санкт-Петербурге начинают охранять иностранн...
# 495                   Путин с коллегами очистили Балтику
# 545    Президент Австрии Хайнц Фишер: "У Евросоюза в ...
# 658    Александр Байер - Пьер Безухов: "Пожалуй, я - ...
# 747    Полиглот Дмитрий Петров: "Килька плавает в том...
# 755                    15 дней, которые потрясли столицу
# 890                                      Карте не место!
# 918                                  Упущенное поколение
# 1080   Нападающий "Арсенала" и сборной России Андрей ...
# 1116                А Вавилонскую башню тоже я разрушил?
# 1174                           "Самая большая ошибка..."
# 1205   Финский хоккеист Леонид Комаров: "Россия - та ...
# 1302                     Евросоюз: два часана забастовку
# 1345                     Легенды, мифы и былипро консула
# 1423   Заглавие:Внучка писателя Леонида Андреева Ирин...
# 1444             Случай с Юлей ПутконенАвтор: Борис Клин
# 1467       Финн-инспекцияАвтор: Елена Шишкунова Наантали
# 1822                                   С Луны свалились
# 2191                          Вестник Северного Мордора
# 2285   Переводчики комиксов предлагают создать словар...
# 2881        Евгений Гришковец: я -- театральный деятель
# 3576                       В пьесе Чехова выросли пальмы
# 4386           Пограничник бежал в Финляндию от дембелей
# 4833                                           Ведомости
# 4841                               Кто заплатит за науку
# 4995                                         Прямая речь
# ...                                                  ...
# 58923                                    Финский Ремарк
# 59398                                         Дипломаты
# 59465                 Оснований для беспокойства нет но
# 59487  Это не единственный пример, мы стремимся испол...
# 59490  Гость редакции _ глава Республики Карелия Алек...
# 59545                                           Персона
# 59656                      Каменщик в седьмом поколении
# 59714  По горизонтали: 1. Роман испанской писательниц...
# 59767                           l Художественные фильмы
# 59984                                Прогулки по городу
# 59991                   Золотой эфес генеральской шашки
# 60088                          Почтальон звонит впустую
# 60109                                На шопинг в Россию
# 60265                                   За родную землю
# 60352                                          Губерния
# 60358  августа День воинской славы России (победа у м...
# 60417                                            Первый
# 60480     Китай не усиливается Он возвращает утраченное
# 60482     Китай не усиливается Он возвращает утраченное
# 60543                                    Вас приглашают
# 60621                      Программируют себя на победу
# 60624                                       Прямая речь
# 60636                         Ученый который спас Киото
# 60774  февраля Международный день редких заболеваний....
# 60868       День войск противовоздушной обороны России.
# 60877           Не счесть китайцев на туристских тропах
# 60917                                   Тиражи и миражи
# 60976                                            Судьба
# 61002                                           Коротко
# 61022                                   Город на въезде
#
#                                                  content  \
# 229    ДЕНИС КАРАУЛЬНОВ Одновременно с чемпионатом Ев...
# 239    В Кракове в возрасте 93 лет скончался польский...
# 297    Сегодня исполняется 75 лет радиостанции "Голос...
# 470    Пилот президентского лайнера обнаружил техниче...
# 475    В северной столице готовится эксперимент по вн...
# 495    "Налогоплательщики Европы должны знать - их де...
# 545    С 1 января Великобритания передаст пост предсе...
# 658    Немецкий актер Александр Байер известен русско...
# 747    Один из лучших переводчиков страны раскрывает ...
# 755    Ровно 50 лет назад, 28 июля 1957 года, в Москв...
# 890    На саммите "большой восьмерки" Япония будет ис...
# 918    В начале августа сбылась мечта - увидел знамен...
# 1080   Вчера в Москву прилетел форвард "Арсенала" Анд...
# 1116   Они преподают цыганам на грузинском и переводя...
# 1174   Прежде чем имя писателя Геннадия Фиша появилос...
# 1205   С нынешнего сезона нападающего хоккейной сборн...
# 1302   Если 50 тысяч сотрудников Евросоюза не получат...
# 1345   Сегодня День дипломатического работника. О про...
# 1423   О забвении Леонида Андреева сегодня говорить н...
# 1444   Продолжается скандал вокруг 9-летней Юли Путко...
# 1467   Дмитрий Медведев и Тарья Халонен обсудили горя...
# 1822   С Луны свалились На воскрешение нацистов понад...
# 2191   Вестник Северного Мордора Инфовойна против Рос...
# 2285   Переводчики комиксов предлагают создать словар...
# 2881   За моноспектакль "Как я съел собаку" Евгений Г...
# 3576   В Петербурге показал "Трех сестер" Национальны...
# 4386   Вчера криминальная полиция Финляндии, расследу...
# 4833   Вторая "Москва--Берлин" Пакет документов о рас...
# 4841   Российским компаниям понадобились ученые Давно...
# 4995   Андрей Козырев, в 1990-1996 годах глава МИД Ро...
# ...                                                  ...
# 58923  Финский Ремарк «Финский Ремарк» Наконец вернул...
# 59398  Дипломаты Дипломаты из народа Ксения КАЙСАЦКАЯ...
# 59465  Оснований для беспокойства нет но Оснований дл...
# 59487  Это не единственный пример, мы стремимся испол...
# 59490  Гость редакции _ глава Республики Карелия Алек...
# 59545  Персона Последний бойскаут Константин Ольхин в...
# 59656  Каменщик в седьмом поколении Каменщик в седьмо...
# 59714  По горизонтали: 1. Роман испанской писательниц...
# 59767  l Художественные фильмы «Разные судьбы» 8.40, ...
# 59984  Прогулки по городу «Коммуна будущего» Ул. Руби...
# 59991  Золотой эфес генеральской шашки В Военно-истор...
# 60088  Почтальон звонит впустую Почтальон звонит впус...
# 60109  На шопинг в Россию На шопинг в Россию Благодар...
# 60265  За родную землю Завтра в 16.00 в музее «Невска...
# 60352  Губерния Не только в Париже Как в «Монрепо» по...
# 60358  9 августа День воинской славы России (победа у...
# 60417  Первый доктор В Сочи названы лауреаты национал...
# 60480  Китай не усиливается Он возвращает утраченное ...
# 60482  Китай не усиливается Он возвращает утраченное ...
# 60543  Вас приглашают Музей печати. Наб. р. Мойки, 32...
# 60621  Программируют себя на победу Программисты из С...
# 60624  Прямая речь Сопредседатель Российско-сирийског...
# 60636  Ученый который спас Киото Ученый, который спас...
# 60774  28 февраля Международный день редких заболеван...
# 60868  День войск противовоздушной обороны России. Вх...
# 60877  Не счесть китайцев на туристских тропах Не сче...
# 60917  Тиражи и миражи Когда стал Ленин маленьким Иль...
# 60976  Судьба Роман с Петербургом Для финской писател...
# 61002  Коротко РОССИЯ. Впервые жители четырех крупных...
# 61022  Город на въезде в Россию Губернатор Ленинградс...
#
#                                          lemmas_headline  \
# 229    ['полиция', 'конфисковать', 'рекордный', 'коли...
# 239    ['кивинять', 'общественный', 'телерадиокомпани...
# 297    ['центрист', 'критиковать', 'реформа', 'соцздр...
# 470    ['россия', 'проигрывать', 'сборная', 'сша', 'ф...
# 475     ['социал-демократ', 'менять', 'свой', 'министр']
# 495    ['москвич', 'элита', 'сюльви', 'кекконен', 'ав...
# 545    ['министр', 'компенсация', 'жертва', 'нарколеп...
# 658    ['финляндия', 'продолжать', 'операция', 'афган...
# 747    ['полиция', 'получать', 'новый', 'инструмент',...
# 755    ['премьер', 'катайнен', 'предупреждать', 'новы...
# 890     ['уровень', 'безработица', 'подниматься', 'май']
# 918    ['в', 'хельсинки', 'выбирать', 'первый', 'Miss...
# 1080   ['финн', 'устанавливать', 'мировой', 'рекорд',...
# 1116   ['на', 'граница', 'российский', 'машина', 'хор...
# 1174       ['интернет', 'что', 'финн', 'старый', 'пить']
# 1205   ['в', 'выборг', 'открываться', 'выставка', '«\...
# 1302   ['пожар', 'локомотив', 'останавливать', 'движе...
# 1345   ['количество', 'заявка', 'санация', 'предприят...
# 1423    ['осенний', 'призыв', 'начинаться', 'финляндия']
# 1444   ['супермощный', 'машина', 'скоро', 'превращать...
# 1467   ['юрка', 'касви', 'праздник', 'развлекательный...
# 1822   ['в', 'сфера', 'лесна', 'промышленность', 'сер...
# 2191    ['горожанин', 'несчастный', 'житель', 'деревня']
# 2285   ['ниинист', 'сознательно', 'рассказывать', 'со...
# 2881   ['финн', 'хотеть', 'вернуться', 'обратно', '19...
# 3576     ['попугай', 'обматерить', 'президент', 'видео']
# 4386   ['финский', 'посол', 'участвовать', 'парад', '...
# 4833   ['женщина', 'хельсинки', 'завещать', 'миллион'...
# 4841   ['президент', 'понимать', 'перспектива', 'член...
# 4995   ['новый', 'министр', 'соцздрав', 'свобода', 'в...
# ...                                                  ...
# 58923                                                NaN
# 59398                                                NaN
# 59465                                                NaN
# 59487                                                NaN
# 59490                                                NaN
# 59545                                                NaN
# 59656                                                NaN
# 59714                                                NaN
# 59767                                                NaN
# 59984                                                NaN
# 59991                                                NaN
# 60088                                                NaN
# 60109                                                NaN
# 60265                                                NaN
# 60352                                                NaN
# 60358                                                NaN
# 60417                                                NaN
# 60480                                                NaN
# 60482                                                NaN
# 60543                                                NaN
# 60621                                                NaN
# 60624                                                NaN
# 60636                                                NaN
# 60774                                                NaN
# 60868                                                NaN
# 60877                                                NaN
# 60917                                                NaN
# 60976                                                NaN
# 61002                                                NaN
# 61022                                                NaN
#
#                                           lemmas_content  \
# 229    ['полиция', 'последний', 'год', 'конфисковать'...
# 239    ['стратегия', 'Yleisradio', 'направлять', 'обс...
# 297    ['представитель', 'центр', 'свой', 'первомайск...
# 470    ['на', 'чемпионат', 'мир', 'хоккей', 'сборная'...
# 475    ['по', 'данный', 'служба', 'новость', 'юля', '...
# 495    ['во', 'время', 'кекконен', 'большинство', 'же...
# 545    ['THL', 'вчера', 'подтвердить', 'вакцина', 'св...
# 658    ['финский', 'миротворец', 'возможно', 'продолж...
# 747    ['общеевропейский', 'реестр', 'Eurodac', 'объе...
# 755    ['правительство', 'готовый', 'пойти', 'новый',...
# 890    ['по', 'сравнение', 'данные', 'прошлый', 'год'...
# 918    ['первый', 'мисс', 'ЛГБТ', 'становиться', 'жит...
# 1080   ['на', 'прошлое', 'первенство', 'мир', 'флорбо...
# 1116   ['по', 'мнение', 'пограничный', 'служба', 'юго...
# 1174   ['новостной', 'служба', 'Yle', 'помощь', 'инте...
# 1205   ['организатор', 'выставка', 'проживать', 'финл...
# 1302   ['к', '21', 'ч', 'движение', 'полностью', 'вос...
# 1345   ['также', 'увеличиваться', 'число', 'обанкроти...
# 1423   ['на', 'служба', 'оборонительный', 'сила', 'пр...
# 1444   ['во', 'двор', 'житель', 'лаппенрант', 'год', ...
# 1467   ['отчуждать', 'финн', 'профессиональный', 'спо...
# 1822   ['представитель', 'лесна', 'промышленность', '...
# 2191   ['вопреки', 'ожидание', 'исслдователь', 'жител...
# 2285   ['по', 'слово', 'президент', 'саули', 'ниинист...
# 2881   ['каждый', 'третий', 'финн', 'считать', 'жить'...
# 3576   ['президент', 'саули', 'ниинист', 'время', 'ви...
# 4386   ['в', 'качество', 'причина', 'отсутствие', 'по...
# 4833   ['на', 'получать', 'средство', 'общество', 'An...
# 4841   ['в', 'время', 'саули', 'ниинист', 'подчеркива...
# 4995   ['36', 'лаура', 'рятя', 'сосредоточиваться', '...
# ...                                                  ...
# 58923                                                NaN
# 59398                                                NaN
# 59465                                                NaN
# 59487                                                NaN
# 59490                                                NaN
# 59545                                                NaN
# 59656                                                NaN
# 59714                                                NaN
# 59767                                                NaN
# 59984                                                NaN
# 59991                                                NaN
# 60088                                                NaN
# 60109                                                NaN
# 60265                                                NaN
# 60352                                                NaN
# 60358                                                NaN
# 60417                                                NaN
# 60480                                                NaN
# 60482                                                NaN
# 60543                                                NaN
# 60621                                                NaN
# 60624                                                NaN
# 60636                                                NaN
# 60774                                                NaN
# 60868                                                NaN
# 60877                                                NaN
# 60917                                                NaN
# 60976                                                NaN
# 61002                                                NaN
# 61022                                                NaN
#
#                                           tokens_content  \
# 229    ['ДЕНИС', 'КАРАУЛЬНОВ', 'Одновременно', 'чемпи...
# 239    ['В', 'Кракове', 'возрасте', 'лет', 'скончался...
# 297    ['Сегодня', 'исполняется', 'лет', 'радиостанци...
# 470    ['Пилот', 'президентского', 'лайнера', 'обнару...
# 475    ['В', 'северной', 'столице', 'готовится', 'экс...
# 495    ['``', 'Налогоплательщики', 'Европы', 'должны'...
# 545    ['С', 'января', 'Великобритания', 'передаст', ...
# 658    ['Немецкий', 'актер', 'Александр', 'Байер', 'и...
# 747    ['Один', 'лучших', 'переводчиков', 'страны', '...
# 755    ['Ровно', 'лет', 'назад', 'июля', 'года', 'Мос...
# 890    ['На', 'саммите', '``', 'большой', 'восьмерки'...
# 918    ['В', 'начале', 'августа', 'сбылась', 'мечта',...
# 1080   ['Вчера', 'Москву', 'прилетел', 'форвард', '``...
# 1116   ['Они', 'преподают', 'цыганам', 'грузинском', ...
# 1174   ['Прежде', 'имя', 'писателя', 'Геннадия', 'Фиш...
# 1205   ['С', 'нынешнего', 'сезона', 'нападающего', 'х...
# 1302   ['Если', 'тысяч', 'сотрудников', 'Евросоюза', ...
# 1345   ['Сегодня', 'День', 'дипломатического', 'работ...
# 1423   ['О', 'забвении', 'Леонида', 'Андреева', 'сего...
# 1444   ['Продолжается', 'скандал', 'вокруг', '9-летне...
# 1467   ['Дмитрий', 'Медведев', 'Тарья', 'Халонен', 'о...
# 1822   ['С', 'Луны', 'свалились', 'На', 'воскрешение'...
# 2191   ['Вестник', 'Северного', 'Мордора', 'Инфовойна...
# 2285   ['Переводчики', 'комиксов', 'предлагают', 'соз...
# 2881   ['За', 'моноспектакль', '``', 'Как', 'съел', '...
# 3576   ['В', 'Петербурге', 'показал', '``', 'Трех', '...
# 4386   ['Вчера', 'криминальная', 'полиция', 'Финлянди...
# 4833   ['Вторая', '``', 'Москва', '--', 'Берлин', "''...
# 4841   ['Российским', 'компаниям', 'понадобились', 'у...
# 4995   ['Андрей', 'Козырев', '1990-1996', 'годах', 'г...
# ...                                                  ...
# 58923  ['Финский', 'Ремарк', 'Финский', 'Ремарк', 'На...
# 59398  ['Дипломаты', 'Дипломаты', 'народа', 'Ксения',...
# 59465  ['Оснований', 'беспокойства', 'Оснований', 'бе...
# 59487  ['Это', 'единственный', 'пример', 'стремимся',...
# 59490  ['Гость', 'редакции', 'глава', 'Республики', '...
# 59545  ['Персона', 'Последний', 'бойскаут', 'Констант...
# 59656  ['Каменщик', 'седьмом', 'поколении', 'Каменщик...
# 59714  ['По', 'горизонтали', 'Роман', 'испанской', 'п...
# 59767  ['l', 'Художественные', 'фильмы', 'Разные', 'с...
# 59984  ['Прогулки', 'городу', 'Коммуна', 'будущего', ...
# 59991  ['Золотой', 'эфес', 'генеральской', 'шашки', '...
# 60088  ['Почтальон', 'звонит', 'впустую', 'Почтальон'...
# 60109  ['На', 'шопинг', 'Россию', 'На', 'шопинг', 'Ро...
# 60265  ['За', 'родную', 'землю', 'Завтра', '16.00', '...
# 60352  ['Губерния', 'Не', 'Париже', 'Как', 'Монрепо',...
# 60358  ['августа', 'День', 'воинской', 'славы', 'Росс...
# 60417  ['Первый', 'доктор', 'В', 'Сочи', 'названы', '...
# 60480  ['Китай', 'усиливается', 'Он', 'возвращает', '...
# 60482  ['Китай', 'усиливается', 'Он', 'возвращает', '...
# 60543  ['Вас', 'приглашают', 'Музей', 'печати', 'Наб'...
# 60621  ['Программируют', 'победу', 'Программисты', 'С...
# 60624  ['Прямая', 'речь', 'Сопредседатель', 'Российск...
# 60636  ['Ученый', 'который', 'спас', 'Киото', 'Ученый...
# 60774  ['февраля', 'Международный', 'день', 'редких',...
# 60868  ['День', 'войск', 'противовоздушной', 'обороны...
# 60877  ['Не', 'счесть', 'китайцев', 'туристских', 'тр...
# 60917  ['Тиражи', 'миражи', 'Когда', 'стал', 'Ленин',...
# 60976  ['Судьба', 'Роман', 'Петербургом', 'Для', 'фин...
# 61002  ['Коротко', 'РОССИЯ', 'Впервые', 'жители', 'че...
# 61022  ['Город', 'въезде', 'Россию', 'Губернатор', 'Л...
#
#                                          tokens_headline
# 229    ['РОССИЙСКУЮ', 'БАСКЕТБОЛЬНУЮ', 'СБОРНУЮ', 'ВО...
# 239                          ['УМЕР', 'ЧЕСЛАВ', 'МИЛОШ']
# 297                   ['ДЕНЬ', 'РОЖДЕНИЯ', 'ПРОПАГАНДЫ']
# 470                          ['Президентский', 'резерв']
# 475    ['В', 'Санкт-Петербурге', 'начинают', 'охранят...
# 495        ['Путин', 'коллегами', 'очистили', 'Балтику']
# 545    ['Президент', 'Австрии', 'Хайнц', 'Фишер', '``...
# 658    ['Александр', 'Байер', 'Пьер', 'Безухов', '``'...
# 747    ['Полиглот', 'Дмитрий', 'Петров', '``', 'Кильк...
# 755           ['дней', 'которые', 'потрясли', 'столицу']
# 890                                   ['Карте', 'место']
# 918                           ['Упущенное', 'поколение']
# 1080   ['Нападающий', '``', 'Арсенала', "''", 'сборно...
# 1116           ['А', 'Вавилонскую', 'башню', 'разрушил']
# 1174   ['``', 'Самая', 'большая', 'ошибка', '...', "''"]
# 1205   ['Финский', 'хоккеист', 'Леонид', 'Комаров', '...
# 1302                ['Евросоюз', 'часана', 'забастовку']
# 1345           ['Легенды', 'мифы', 'былипро', 'консула']
# 1423   ['Заглавие', 'Внучка', 'писателя', 'Леонида', ...
# 1444   ['Случай', 'Юлей', 'ПутконенАвтор', 'Борис', '...
# 1467   ['Финн-инспекцияАвтор', 'Елена', 'Шишкунова', ...
# 1822                          ['С', 'Луны', 'свалились']
# 2191                 ['Вестник', 'Северного', 'Мордора']
# 2285   ['Переводчики', 'комиксов', 'предлагают', 'соз...
# 2881   ['Евгений', 'Гришковец', '--', 'театральный', ...
# 3576       ['В', 'пьесе', 'Чехова', 'выросли', 'пальмы']
# 4386   ['Пограничник', 'бежал', 'Финляндию', 'дембелей']
# 4833                                       ['Ведомости']
# 4841                        ['Кто', 'заплатит', 'науку']
# 4995                                  ['Прямая', 'речь']
# ...                                                  ...
# 58923                              ['Финский', 'Ремарк']
# 59398                                      ['Дипломаты']
# 59465                      ['Оснований', 'беспокойства']
# 59487  ['Это', 'единственный', 'пример', 'стремимся',...
# 59490  ['Гость', 'редакции', 'глава', 'Республики', '...
# 59545                                        ['Персона']
# 59656               ['Каменщик', 'седьмом', 'поколении']
# 59714  ['По', 'горизонтали', 'Роман', 'испанской', 'п...
# 59767                  ['l', 'Художественные', 'фильмы']
# 59984                             ['Прогулки', 'городу']
# 59991       ['Золотой', 'эфес', 'генеральской', 'шашки']
# 60088                 ['Почтальон', 'звонит', 'впустую']
# 60109                         ['На', 'шопинг', 'Россию']
# 60265                          ['За', 'родную', 'землю']
# 60352                                       ['Губерния']
# 60358  ['августа', 'День', 'воинской', 'славы', 'Росс...
# 60417                                         ['Первый']
# 60480  ['Китай', 'усиливается', 'Он', 'возвращает', '...
# 60482  ['Китай', 'усиливается', 'Он', 'возвращает', '...
# 60543                              ['Вас', 'приглашают']
# 60621                        ['Программируют', 'победу']
# 60624                                 ['Прямая', 'речь']
# 60636             ['Ученый', 'который', 'спас', 'Киото']
# 60774  ['февраля', 'Международный', 'день', 'редких',...
# 60868  ['День', 'войск', 'противовоздушной', 'обороны...
# 60877  ['Не', 'счесть', 'китайцев', 'туристских', 'тр...
# 60917                               ['Тиражи', 'миражи']
# 60976                                         ['Судьба']
# 61002                                        ['Коротко']
# 61022                                ['Город', 'въезде']
#
# [607 rows x 10 columns]

# %%
# Get content and heading for the rows [a,b,c] :

print("Results for {}".format(search_string))
#rows = results.index
rows = [1467]
for r in rows:
    print("="*90)
    print('row {}'.format(r))
    print('Headline: \n {} \n'.format(data.iloc[r].headline))
    print('Content: \n {} \n'.format(data.iloc[r].content))
# Out:
# Results for переводчик
# ==========================================================================================
# row 1467
# Headline:
#  Финн-инспекцияАвтор: Елена Шишкунова Наантали
#
# Content:
