# %%
# System libraries:
# %load_ext autoreload
import pandas as pd
import json
import nltk
import numpy as np
import os
import sys
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv('/var/www/html/work/compressed/data/russia_finland/processed/yle_ru_processed.csv')
data.iloc[:5]
# Out:
#   authors                                            content coverage  \
# 0     NaN   Министр по вопросам окружающей среды Вилле Ни...    local
# 1     NaN   Труд финских работников занимает 8-е по дорог...    local
# 2     NaN   На дорогах Южной Финляндии летние ограничения...    local
# 3     NaN   В Хельсинкском надворном суде начинается расс...    local
# 4     NaN   Несмотря на все усилия и различные кампании п...    local
#
#               datePublished  \
# 0  2013-04-07T20:12:33+0300
# 1  2013-04-07T20:50:16+0300
# 2  2013-04-08T08:38:40+0300
# 3  2013-04-08T08:57:17+0300
# 4  2013-04-08T09:18:42+0300
#
#                                             headline         id sources  \
# 0  Министр окружающей среды Ниинистё хочет переве...  3-6594601     NaN
# 1          Финский труд дешевле, чем труд в Германии  3-6594603     NaN
# 2  Начинается постепенный переход на летнее огран...  3-6594605     NaN
# 3  В надворном суде начинается разбирательство по...  3-6594611     NaN
# ...

# %%
#Get articles by keywords:

# Enter your search string:
search_string = 'карельский'
results = data[data['content'].str.contains(search_string)]

# Get all results matching search string
results
# Out:
#                                                  authors  \
# 984    [{'name': 'Служба новостей Yle', 'organization...
# 1545   [{'name': 'Служба новостей Yle', 'organization...
# 3604   [{'name': 'Lioubov Shalygina', 'organization':...
# 4282   [{'name': 'Maxim Fedorov', 'organization': 'Yl...
# 7178   [{'name': 'Служба новостей Yle', 'organization...
# 8201   [{'name': 'Служба новостей Yle', 'organization...
# 8224   [{'name': 'Lioubov Shalygina', 'organization':...
# 9586   [{'name': 'Maxim Fedorov', 'organization': 'Yl...
# 10248  [{'name': 'Служба новостей Yle', 'organization...
# 10778  [{'name': 'Служба новостей Yle', 'organization...
# 13740  [{'name': 'Служба новостей Yle', 'organization...
# 18399                                                NaN
# 18493                                                NaN
# 23961                                                NaN
#
#                                                  content coverage  \
# ...

# %%
# Get content and heading for the rows [a,b,c] :

print("Results for {}".format(search_string))
#rows = results.index
rows = [18493]
for r in rows:
    print("="*90)
    print('row {}'.format(r))
    print('Headline: \n {} \n'.format(data.iloc[r].headline))
    print('Content: \n {} \n'.format(data.iloc[r].content))
    print('URL: \n {} \n'.format(data.iloc[r].url))
# Out:
# Results for карельский
# ...
# row 18493
# Headline:
#  "Викиликс": Путин назвал Халонен "опасной женщиной"
#
# Content:
#   Один из обнародованных на сайте "Викиликс" документов касается встречи президентов Тарьи Халонен и Владимира Путина в 2000 году.  В частности, главы Финляндии и России обсуждали карельский вопрос, хотя он и не значился в официальном протоколе. Путин сказал, что Сталин совершил ошибку, напав на Финляндию в Зимнюю войну. По мнению российского президента, «У России было достаточно территорий, и ей не надо было обороняться». Тем не менее, Путин посчитал, что продолжающееся обсуждение Карелии может негативно сказаться на финско-российских отношениях. Согласно депеше, Халонен перед Путиным отстаивала свою точку зрения на этот счет. В один из моментов Путин саркастически заметил: «Вы очень опасная женщина».
#
# URL:
#  {'short': 'http://yle.fi/uutiset/6597046', 'full': 'http://yle.fi/uutiset/osasto/novosti/vikiliks_putin_nazval_khalonen_opasnoi_zhenshchinoi/6597046'}

# %%
# %ls /var/www/html/work/compressed/data/russia_finland/processed
